# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
guess = 0.0
cube = 27.0
increment = 0.2
epsilon = 0.1  # error tolerance

# %%
# Method 1 using While loop
point = []
while abs(guess**3 - cube) >= epsilon:
    guess += increment
    point.append(guess)

# checking approx value
if abs(guess**3 - cube) >= epsilon:
    print("Approx values using While loop : ")
    print("Failed on the cube root of", cube)
else:
    print("Approx values using While loop : ")
    print(guess, "is close to the cube root of", cube)
# Out:
# Approx values using While loop :
# 3.0000000000000004 is close to the cube root of 27.0

# %%
# plotting the guessed value and error (guess**3 - cube)
error = [(guess**3 - cube)]

for i in point:
    plt.plot(i, error)
plt.xlabel('Guessed Value')
plt.ylabel('Error')
plt.show()
